// %% [markdown]
// ## Guns

// %%
clear all
import delimited state_factors.csv
list in 1/15
// Out:
// (34 vars, 51 obs)
//
//
//      +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
//   1. |        state | vehicles | mur~2002 | rou~2002 | robbery | fssgun | pgun2 | pblack | gunmur~r | suicide |   gdp | murder | roundm~r | pgun |     ngun | pi | southe~s | purban | yearad~d | testsc~e | pnonwh~e | latitude | geogra~y | popula~n |
//      |      Wyoming |     1140 |      4.6 |        5 |      17 |     74 | 22827 |   1.29 |       .9 |    19.7 | 54305 |    1.4 |        1 | 59.7 |   500500 |  2 |        0 |     65 |     1890 |      514 |       14 |       42 |        0 |       .6 |
// ...

// %%
reg
