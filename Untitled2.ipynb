// %%
use https://www.stata.com/data/s4poe4/njmin3.dta

// %%
summ
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//           nj |        820    .8073171    .3946469          0          1
//            d |        820          .5    .5003052          0          1
//         d_nj |        820    .4036585      .49093          0          1
//          fte |        794    21.02651    9.422746          0         85
//           bk |        820    .4170732    .4933761          0          1
// -------------+---------------------------------------------------------
//          kfc |        820     .195122    .3965364          0          1
//         roys |        820    .2414634    .4282318          0          1
//       wendys |        820    .1463415    .3536639          0          1
//     co_owned |        820    .3439024    .4752989          0          1
//     centralj |        820    .1536585    .3608412          0          1
// -------------+---------------------------------------------------------
//       southj |        820    .2268293    .4190369          0          1
//          pa1 |        820    .0878049    .2831836          0          1
//          pa2 |        820     .104878    .3065832          0          1
//         demp |        768   -.0704427    9.016441      -41.5         34

// %%
bysort nj d: summarize fte
// Out:
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// -> nj = 0, d = 0
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//          fte |         77    23.33117    11.85628        7.5       70.5
//
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// -> nj = 0, d = 1
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//          fte |         77    21.16558    8.276732          0       43.5
//
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// -> nj = 1, d = 0
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//          fte |        321    20.43941    9.106239          5         85
//
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// -> nj = 1, d = 1
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//          fte |        319    21.02743    9.293024          0       60.5

// %%
reg fte nj d d_nj
// Out:
//       Source |       SS           df       MS      Number of obs   =       794
// -------------+----------------------------------   F(3, 790)       =      1.96
//        Model |  521.116463         3  173.705488   Prob > F        =    0.1180
//     Residual |   69887.878       790  88.4656683   R-squared       =    0.0074
// -------------+----------------------------------   Adj R-squared   =    0.0036
//        Total |  70408.9944       793  88.7881393   Root MSE        =    9.4056
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//           nj |  -2.891761   1.193524    -2.42   0.016    -5.234614   -.5489079
//            d |  -2.165584   1.515853    -1.43   0.154     -5.14116    .8099912
//         d_nj |   2.753606   1.688409     1.63   0.103     -.560693    6.067905
//        _cons |   23.33117    1.07187    21.77   0.000     21.22712    25.43522
// ------------------------------------------------------------------------------

// %%
lincom _cons + nj
// Out:
//  ( 1)  nj + _cons = 0
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//          (1) |   20.43941   .5249705    38.93   0.000     19.40891    21.46991
// ------------------------------------------------------------------------------

// %%
estimates store did

lincom _cons + nj
lincom _cons + d
lincom _cons + nj + d  + d_nj
lincom (_cons + nj + d + d_nj)-(_cons + d)-((_cons + nj)-_cons)
// Out:
//       Source |       SS           df       MS      Number of obs   =       794
// -------------+----------------------------------   F(3, 790)       =      1.96
//        Model |  521.116463         3  173.705488   Prob > F        =    0.1180
//     Residual |   69887.878       790  88.4656683   R-squared       =    0.0074
// -------------+----------------------------------   Adj R-squared   =    0.0036
//        Total |  70408.9944       793  88.7881393   Root MSE        =    9.4056
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//           nj |  -2.891761   1.193524    -2.42   0.016    -5.234614   -.5489079
//            d |  -2.165584   1.515853    -1.43   0.154     -5.14116    .8099912
//         d_nj |   2.753606   1.688409     1.63   0.103     -.560693    6.067905
//        _cons |   23.33117    1.07187    21.77   0.000     21.22712    25.43522
// ------------------------------------------------------------------------------
//
//
//
//  ( 1)  nj + _cons = 0
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//          (1) |   20.43941   .5249705    38.93   0.000     19.40891    21.46991
// ------------------------------------------------------------------------------
//
//
//  ( 1)  d + _cons = 0
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//          (1) |   21.16558    1.07187    19.75   0.000     19.06153    23.26963
// ------------------------------------------------------------------------------
//
//
//  ( 1)  nj + d + d_nj + _cons = 0
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//          (1) |   21.02743   .5266136    39.93   0.000      19.9937    22.06116
// ------------------------------------------------------------------------------
//
//
//  ( 1)  d_nj = 0
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//          (1) |   2.753606   1.688409     1.63   0.103     -.560693    6.067905
// ------------------------------------------------------------------------------

// %%
reg fte nj d d_nj kfc roys wendys co_owned
// Out:
//       Source |       SS           df       MS      Number of obs   =       794
// -------------+----------------------------------   F(7, 786)       =     27.45
//        Model |  13830.4328         7  1975.77611   Prob > F        =    0.0000
//     Residual |  56578.5617       786  71.9829029   R-squared       =    0.1964
// -------------+----------------------------------   Adj R-squared   =    0.1893
//        Total |  70408.9944       793  88.7881393   Root MSE        =    8.4843
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//           nj |  -2.376608   1.079192    -2.20   0.028    -4.495048   -.2581683
//            d |  -2.223565   1.367692    -1.63   0.104    -4.908327    .4611969
//         d_nj |   2.845067   1.523338     1.87   0.062    -.1452267     5.83536
//          kfc |  -10.45339   .8489569   -12.31   0.000    -12.11988   -8.786899
//         roys |  -1.624999    .859798    -1.89   0.059    -3.312771    .0627729
//       wendys |  -1.063709   .9291502    -1.14   0.253    -2.887618     .760201
//     co_owned |  -1.168545   .7161662    -1.63   0.103     -2.57437    .2372794
//        _cons |   25.95118   1.038223    25.00   0.000     23.91316    27.98919
// ------------------------------------------------------------------------------

// %%
reg fte nj d d_nj kfc roys wendys co_owned southj centralj pa1
// Out:
//       Source |       SS           df       MS      Number of obs   =       794
// -------------+----------------------------------   F(10, 783)      =     22.26
//        Model |  15588.2941        10  1558.82941   Prob > F        =    0.0000
//     Residual |  54820.7003       783  70.0136658   R-squared       =    0.2214
// -------------+----------------------------------   Adj R-squared   =    0.2115
//        Total |  70408.9944       793  88.7881393   Root MSE        =    8.3674
//
// ------------------------------------------------------------------------------
//          fte |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//           nj |  -.9079636   1.271742    -0.71   0.475    -3.404391    1.588463
//            d |  -2.211851    1.34886    -1.64   0.101     -4.85966    .4359581
//         d_nj |   2.814908   1.502382     1.87   0.061    -.1342646    5.764081
//          kfc |    -10.058   .8446711   -11.91   0.000    -11.71609   -8.399914
//         roys |  -1.693393   .8591837    -1.97   0.049    -3.379969   -.0068164
//       wendys |  -1.064952   .9206385    -1.16   0.248    -2.872164    .7422598
//     co_owned |  -.7163097   .7189905    -1.00   0.319    -2.127687    .6950674
//       southj |  -3.701761   .7799532    -4.75   0.000    -5.232807   -2.170714
//     centralj |   .0078834   .8974936     0.01   0.993    -1.753895    1.769662
//          pa1 |    .923862   1.384928     0.67   0.505    -1.794749    3.642473
//        _cons |   25.32051   1.210903    20.91   0.000     22.94351    27.69751
// ------------------------------------------------------------------------------
