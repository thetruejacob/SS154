// %% [markdown]
// Using okun.dat (https://www.stata.com/data/s4poe4/okun.dta) replicate the finite distributed lags example in Section 9.2 (p. 341, HGL). Obtain the findings in Table 9.2 and also obtain the correlogram (like in Figure 9.8) for the unemployment with 24 lags (syntax is "ac," see https://www.stata.com/manuals/tscorrgram.pdf). Note that the lag operator in Stata is "L." (e.g., L.u means the first lag of u and L(1/2).u means the first and second lags of u).

// %%
clear all 
use https://www.stata.com/data/s4poe4/okun.dta

summ

gen date = tq(1985q2) + _n-1
format %tq date
tsset date

tsline u g
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//            g |         98    1.276531    .6469279       -1.4        2.5
//            u |         98    5.704082    1.132638        3.9        9.6
//
//
//
//         time variable:  date, 1985q2 to 2009q3
//                 delta:  1 quarter
// This front-end cannot display the desired image type.

// %%
regress D.u L(0/3).g
// Out:
//       Source |       SS           df       MS      Number of obs   =        95
// -------------+----------------------------------   F(4, 90)        =     42.23
//        Model |  5.13367789         4  1.28341947   Prob > F        =    0.0000
//     Residual |  2.73516422        90  .030390714   R-squared       =    0.6524
// -------------+----------------------------------   Adj R-squared   =    0.6370
//        Total |  7.86884211        94  .083711086   Root MSE        =    .17433
//
// ------------------------------------------------------------------------------
//          D.u |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//            g |
//          --. |  -.2020526   .0330131    -6.12   0.000     -.267639   -.1364663
//          L1. |  -.1645352   .0358175    -4.59   0.000    -.2356929   -.0933774
//          L2. |   -.071556   .0353043    -2.03   0.046    -.1416941   -.0014179
//          L3. |    .003303   .0362603     0.09   0.928    -.0687345    .0753405
//              |
//        _cons |   .5809746   .0538893    10.78   0.000     .4739142     .688035
// ------------------------------------------------------------------------------

// %% [markdown]
// Using phillips_aus.dat (https://www.stata.com/data/s4poe4/phillips_aus.dta) replicate the ARDL given in Equation 9.57 (p. 368, HGL). Obtain the findings in Table 9.4. What is your conclusion after checking AIC and SC? (syntax for AIC and SC is "estat ic")

// %%
clear all
use https://www.stata.com/data/s4poe4/phillips_aus.dta

gen date = tq(1981q1) + _n-1
format %tq date
tsset date
summ
// Out:
//         time variable:  date, 1981q1 to 2003q3
//                 delta:  1 quarter
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//          inf |         91    .8043956    .6458263        -.4        2.6
//            u |         91    7.034066    1.818804          4       10.8
//         date |         91         129    26.41338         84        174

// %%
reg L(0/4).inf D.u
// Out:
//       Source |       SS           df       MS      Number of obs   =        87
// -------------+----------------------------------   F(5, 81)        =     13.71
//        Model |  15.4337676         5  3.08675353   Prob > F        =    0.0000
//     Residual |  18.2333588        81  .225103195   R-squared       =    0.4584
// -------------+----------------------------------   Adj R-squared   =    0.4250
//        Total |  33.6671264        86  .391478214   Root MSE        =    .47445
//
// ------------------------------------------------------------------------------
//          inf |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//          inf |
//          L1. |   .2354401   .1015555     2.32   0.023     .0333765    .4375037
//          L2. |    .121328   .1037571     1.17   0.246    -.0851161    .3277722
//          L3. |   .1676895   .1049597     1.60   0.114    -.0411473    .3765264
//          L4. |   .2819156   .1013801     2.78   0.007      .080201    .4836302
//              |
//            u |
//          D1. |  -.7901718   .1885334    -4.19   0.000    -1.165294   -.4150496
//              |
//        _cons |   .1000999   .0982599     1.02   0.311    -.0954064    .2956063
// ------------------------------------------------------------------------------

// %%
program modelsel
    scalar aic = ln(e(rss)/e(N))+2*e(rank)/e(N)
    scalar sc = ln(e(rss)/e(N))+e(rank)*ln(e(N))/e(N)
    scalar obs = e(N)
    scalar list aic sc obs
end

// %%
quietly regress inf L.inf L(0/1).D.u
modelsel
// Out:
//        aic =  -1.255973
//         sc = -1.1441242
//        obs =         89

// %%
forvalues q=0/1 {
    forvalues p=1/6 {
    quietly regress L(0/`p').inf L(0/`q').D.u if date >= tq(1988q3)
    display "p=`p' q=`q'"
    modelsel
    }
}
// Out:
// p=1 q=0
//        aic = -1.7145721
//         sc = -1.6107586
//        obs =         61
// p=2 q=0
//        aic = -1.6827262
//         sc = -1.5443083
//        obs =         61
// p=3 q=0
//        aic = -1.6617917
//         sc = -1.4887692
//        obs =         61
// p=4 q=0
//        aic = -1.6495316
//         sc = -1.4419047
//        obs =         61
// p=5 q=0
//        aic = -1.6175512
//         sc = -1.3753198
//        obs =         61
// p=6 q=0
//        aic = -1.5892517
//         sc = -1.3124158
//        obs =         61
// p=1 q=1
//        aic = -1.6893953
//         sc = -1.5509773
//        obs =         61
// p=2 q=1
//        aic = -1.6578292
//         sc = -1.4848067
//        obs =         61
// p=3 q=1
//        aic = -1.6362272
//         sc = -1.4286002
//        obs =         61
// p=4 q=1
//        aic = -1.6189343
//         sc = -1.3767029
//        obs =         61
// p=5 q=1
//        aic = -1.5875147
//         sc = -1.3106788
//        obs =         61
// p=6 q=1
//        aic = -1.5600387
//         sc = -1.2485983
//        obs =         61

// %%
reg L(0/4).inf D.u if date > tq(1986q2)
estat ic
// Out:
//       Source |       SS           df       MS      Number of obs   =        69
// -------------+----------------------------------   F(5, 63)        =      3.74
//        Model |  3.01253229         5  .602506457   Prob > F        =    0.0050
//     Residual |  10.1451489        63  .161034109   R-squared       =    0.2290
// -------------+----------------------------------   Adj R-squared   =    0.1678
//        Total |  13.1576812        68  .193495311   Root MSE        =    .40129
//
// ------------------------------------------------------------------------------
//          inf |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//          inf |
//          L1. |    .385352   .1193678     3.23   0.002     .1468146    .6238895
//          L2. |  -.0545529   .1278789    -0.43   0.671    -.3100985    .2009928
//          L3. |   .0214829   .1283735     0.17   0.868    -.2350511     .278017
//          L4. |   .1454277   .1231088     1.18   0.242    -.1005855     .391441
//              |
//            u |
//          D1. |  -.5599137   .2368341    -2.36   0.021    -1.033189   -.0866385
//              |
//        _cons |   .2834255   .1222165     2.32   0.024     .0391953    .5276557
// ------------------------------------------------------------------------------
//
//
// Akaike's information criterion and Bayesian information criterion
//
// -----------------------------------------------------------------------------
//        Model |          N   ll(null)  ll(model)      df        AIC        BIC
// -------------+---------------------------------------------------------------
//            . |         69  -40.73678  -31.76643       6   75.53287   88.93751
// -----------------------------------------------------------------------------
// Note: BIC uses N = number of observations. See [R] BIC note.

// %%
clear all
use https://www.stata.com/data/s4poe4/consumptn.dta

// %%
summ
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//      incgwth |        200       1.735    .9869882       -1.1          6
//      durgwth |        200       1.643    3.040506       -8.7       12.4
//      congwth |        200       1.747    .8221745       -2.1        4.2

// %%
gen date = tq(1960q1) + _n-1
format %tq date
tsset date
// Out:
//         time variable:  date, 1960q1 to 2009q4
//                 delta:  1 quarter

// %%
tsline congwth, yline(1.747)

tsline incgwth, yline(1.735)
// Out:
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.

// %%
reg L(0/2).congwth incgwth
estat ic
// Out:
//       Source |       SS           df       MS      Number of obs   =       198
// -------------+----------------------------------   F(3, 194)       =     47.27
//        Model |  56.6265006         3  18.8755002   Prob > F        =    0.0000
//     Residual |  77.4684994       194  .399322162   R-squared       =    0.4223
// -------------+----------------------------------   Adj R-squared   =    0.4134
//        Total |     134.095       197  .680685279   Root MSE        =    .63192
//
// ------------------------------------------------------------------------------
//      congwth |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      congwth |
//          L1. |    .151559   .0655483     2.31   0.022     .0222802    .2808378
//          L2. |    .286677   .0617625     4.64   0.000     .1648648    .4084892
//              |
//      incgwth |   .3305265   .0509525     6.49   0.000     .2300346    .4310184
//        _cons |   .4065232   .1258212     3.23   0.001     .1583701    .6546763
// ------------------------------------------------------------------------------
//
//
// Akaike's information criterion and Bayesian information criterion
//
// -----------------------------------------------------------------------------
//        Model |          N   ll(null)  ll(model)      df        AIC        BIC
// -------------+---------------------------------------------------------------
//            . |        198  -242.3677  -188.0487       4   384.0973   397.2504
// -----------------------------------------------------------------------------
// Note: BIC uses N = number of observations. See [R] BIC note.

// %%
ac res
// Out:
// This front-end cannot display the desired image type.

// %%
reg L(0/2).congwth incgwth

// %%
*LM test is: e_hat_t = gamma_1 + gamma_2 X_t + rho e_hat_t-1*/
reg congwth incgwth L(1/2).res

reg res incgwth L1.res //LM test for one lag
  *estat archlm, lag(1/20)
display 0.0004*199
display chi2tail(1,.0796)
display "P-value is larger than 0.05. Therefore do not reject null. Null is NO serial correlation "
// Out:
//       Source |       SS           df       MS      Number of obs   =       198
// -------------+----------------------------------   F(3, 194)       =     40.53
//        Model |  51.6613269         3  17.2204423   Prob > F        =    0.0000
//     Residual |  82.4336731       194  .424915841   R-squared       =    0.3853
// -------------+----------------------------------   Adj R-squared   =    0.3758
//        Total |     134.095       197  .680685279   Root MSE        =    .65186
//
// ------------------------------------------------------------------------------
//      congwth |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      incgwth |   .4077265   .0520498     7.83   0.000     .3050704    .5103825
//              |
//          res |
//          L1. |   .0409545   .0738905     0.55   0.580    -.1047774    .1866863
//          L2. |   .3504586   .0682657     5.13   0.000     .2158204    .4850967
//              |
//        _cons |   1.040628   .1016112    10.24   0.000     .8402231    1.241032
// ------------------------------------------------------------------------------
//
//
//       Source |       SS           df       MS      Number of obs   =       199
// -------------+----------------------------------   F(2, 196)       =      0.04
//        Model |  .033608434         2  .016804217   Prob > F        =    0.9655
//     Residual |  93.7536713       196  .478335058   R-squared       =    0.0004
// -------------+----------------------------------   Adj R-squared   =   -0.0098
//        Total |  93.7872797       198   .47367313   Root MSE        =    .69162
//
// ------------------------------------------------------------------------------
//          res |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      incgwth |  -.0067653   .0544762    -0.12   0.901    -.1142001    .1006695
//              |
//          res |
//          L1. |   .0206978   .0782511     0.26   0.792    -.1336243    .1750199
//              |
//        _cons |   .0141931   .1065046     0.13   0.894     -.195849    .2242352
// ------------------------------------------------------------------------------
//
// .0796
//
// .77784021
//
// P-value is larger than 0.05. Therefore do not reject null. Null is NO serial correlation

// %%
reg res incgwth L1.res L2.res //LM test for two lags
 *estat archlm, lag(1/20)
display "LM = T*R^2 =" 198*0.1200
display "P-Value =" chi2tail(1,23.76)
display "P-value is much smaller than 0.05. Therefore REJECT the null. Null is NO serial correlation."
// Out:
//       Source |       SS           df       MS      Number of obs   =       198
// -------------+----------------------------------   F(3, 194)       =      8.82
//        Model |  11.2369366         3  3.74564553   Prob > F        =    0.0000
//     Residual |  82.4336731       194  .424915841   R-squared       =    0.1200
// -------------+----------------------------------   Adj R-squared   =    0.1064
//        Total |  93.6706097       197  .475485328   Root MSE        =    .65186
//
// ------------------------------------------------------------------------------
//          res |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      incgwth |  -.0492698   .0520498    -0.95   0.345    -.1519258    .0533863
//              |
//          res |
//          L1. |   .0409545   .0738905     0.55   0.580    -.1047774    .1866863
//          L2. |   .3504586   .0682657     5.13   0.000     .2158204    .4850967
//              |
//        _cons |    .086516   .1016112     0.85   0.396    -.1138885    .2869204
// ------------------------------------------------------------------------------
//
// LM = T*R^2 =23.76
//
// P-Value =1.091e-06
//
// P-value is much smaller than 0.05. Therefore REJECT the null. Null is NO serial correlation.

// %%
reg L(0/1).congwth incgwth
estat ic
// Out:
//       Source |       SS           df       MS      Number of obs   =       199
// -------------+----------------------------------   F(2, 196)       =     54.32
//        Model |  47.8211116         2  23.9105558   Prob > F        =    0.0000
//     Residual |  86.2763758       196  .440185591   R-squared       =    0.3566
// -------------+----------------------------------   Adj R-squared   =    0.3500
//        Total |  134.097487       198  .677260038   Root MSE        =    .66346
//
// ------------------------------------------------------------------------------
//      congwth |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      congwth |
//          L1. |   .2634749   .0637845     4.13   0.000     .1376829     .389267
//              |
//      incgwth |   .3600599   .0530379     6.79   0.000     .2554616    .4646581
//        _cons |   .6636615   .1189324     5.58   0.000     .4291101    .8982129
// ------------------------------------------------------------------------------
//
//
// Akaike's information criterion and Bayesian information criterion
//
// -----------------------------------------------------------------------------
//        Model |          N   ll(null)  ll(model)      df        AIC        BIC
// -------------+---------------------------------------------------------------
//            . |        199  -243.0924  -199.2117       3   404.4235   414.3034
// -----------------------------------------------------------------------------
// Note: BIC uses N = number of observations. See [R] BIC note.

// %%
reg L(0/1).congwth incgwth
predict parta, res
ac parta
// Out:
//       Source |       SS           df       MS      Number of obs   =       199
// -------------+----------------------------------   F(2, 196)       =     54.32
//        Model |  47.8211116         2  23.9105558   Prob > F        =    0.0000
//     Residual |  86.2763758       196  .440185591   R-squared       =    0.3566
// -------------+----------------------------------   Adj R-squared   =    0.3500
//        Total |  134.097487       198  .677260038   Root MSE        =    .66346
//
// ------------------------------------------------------------------------------
//      congwth |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      congwth |
//          L1. |   .2634749   .0637845     4.13   0.000     .1376829     .389267
//              |
//      incgwth |   .3600599   .0530379     6.79   0.000     .2554616    .4646581
//        _cons |   .6636615   .1189324     5.58   0.000     .4291101    .8982129
// ------------------------------------------------------------------------------
//
// (1 missing value generated)
// This front-end cannot display the desired image type.

// %%
predict resids, res
// Out:
// (2 missing values generated)

// %%
ac resids
// Out:
// This front-end cannot display the desired image type.

// %%
reg congwth incgwth
estat ic
// Out:
//       Source |       SS           df       MS      Number of obs   =       200
// -------------+----------------------------------   F(1, 198)       =     85.25
//        Model |  40.4857511         1  40.4857511   Prob > F        =    0.0000
//     Residual |  94.0324489       198  .474911358   R-squared       =    0.3010
// -------------+----------------------------------   Adj R-squared   =    0.2974
//        Total |    134.5182       199  .675970854   Root MSE        =    .68914
//
// ------------------------------------------------------------------------------
//      congwth |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      incgwth |   .4569962   .0494957     9.23   0.000     .3593898    .5546027
//        _cons |   .9541116   .0987375     9.66   0.000     .7593995    1.148824
// ------------------------------------------------------------------------------
//
//
// Akaike's information criterion and Bayesian information criterion
//
// -----------------------------------------------------------------------------
//        Model |          N   ll(null)  ll(model)      df        AIC        BIC
// -------------+---------------------------------------------------------------
//            . |        200  -244.1259    -208.32       2   420.6399   427.2366
// -----------------------------------------------------------------------------
// Note: BIC uses N = number of observations. See [R] BIC note.

// %%
reg L(0/2).congwth incgwth
predict partb, resid
ac partb
// Out:
//       Source |       SS           df       MS      Number of obs   =       198
// -------------+----------------------------------   F(3, 194)       =     47.27
//        Model |  56.6265006         3  18.8755002   Prob > F        =    0.0000
//     Residual |  77.4684994       194  .399322162   R-squared       =    0.4223
// -------------+----------------------------------   Adj R-squared   =    0.4134
//        Total |     134.095       197  .680685279   Root MSE        =    .63192
//
// ------------------------------------------------------------------------------
//      congwth |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      congwth |
//          L1. |    .151559   .0655483     2.31   0.022     .0222802    .2808378
//          L2. |    .286677   .0617625     4.64   0.000     .1648648    .4084892
//              |
//      incgwth |   .3305265   .0509525     6.49   0.000     .2300346    .4310184
//        _cons |   .4065232   .1258212     3.23   0.001     .1583701    .6546763
// ------------------------------------------------------------------------------
//
// (2 missing values generated)
// This front-end cannot display the desired image type.

// %%
reg congwth L(1/2).congwth L14.congwth L16.congwth incgwth
predict res_lag14, r
ac res_lag14
// Out:
//       Source |       SS           df       MS      Number of obs   =       184
// -------------+----------------------------------   F(5, 178)       =     29.44
//        Model |  56.0853224         5  11.2170645   Prob > F        =    0.0000
//     Residual |  67.8202755       178  .381012783   R-squared       =    0.4526
// -------------+----------------------------------   Adj R-squared   =    0.4373
//        Total |  123.905598       183   .67707977   Root MSE        =    .61726
//
// ------------------------------------------------------------------------------
//      congwth |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      congwth |
//          L1. |   .1094467   .0681179     1.61   0.110    -.0249758    .2438692
//          L2. |   .2760602    .063977     4.31   0.000     .1498092    .4023111
//         L14. |  -.1002618   .0686294    -1.46   0.146    -.2356938    .0351702
//         L16. |   .2759813   .0685453     4.03   0.000     .1407154    .4112472
//              |
//      incgwth |   .3006274   .0507298     5.93   0.000     .2005181    .4007367
//        _cons |    .246888   .1584508     1.56   0.121    -.0657958    .5595719
// ------------------------------------------------------------------------------
//
// (16 missing values generated)
// This front-end cannot display the desired image type.

// %%
estat ic
// Out:
// Akaike's information criterion and Bayesian information criterion
//
// -----------------------------------------------------------------------------
//        Model |          N   ll(null)  ll(model)      df        AIC        BIC
// -------------+---------------------------------------------------------------
//            . |        184  -224.7064  -169.2618       6   350.5237   369.8133
// -----------------------------------------------------------------------------
// Note: BIC uses N = number of observations. See [R] BIC note.
