// %%
clear

import delimited data.csv

summ
// Out:
// (17 vars, 3,712 obs)
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//           v1 |      3,712    2815.135    1601.278          0       5647
//           q3 |      3,712    2.800108    1.047212          1          5
//           q4 |      3,712    2.470366    1.044515          1          5
//           q5 |      3,712    2.892511      1.1012          1          5
//           q6 |      3,712    2.659213     1.06206          1          5
// -------------+---------------------------------------------------------
//           q7 |      3,712    3.475754    1.153512          1          5
//           q8 |      3,712    2.365302    1.157573          1          5
//           q9 |      3,712    2.713093    1.267023          1          5
//  assessments |      3,712    .4418103    .4966693          0          1
// ...

// %% [markdown]
// ## Q3

// %%
ologit q3 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application i.videos i.diagrams, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application 1.videos 1.diagrams)

ologit q3 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application)
// Out:
// Ordered logistic regression                     Number of obs     =      3,712
//                                                 LR chi2(9)        =     125.76
//                                                 Prob > chi2       =     0.0000
// Log likelihood = -5263.2701                     Pseudo R2         =     0.0118
//
// -------------------------------------------------------------------------------
//            q3 |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// 1.assessments |   .2276797   .0616589     3.69   0.000     .1068304     .348529
// 1.explanation |   .3411745   .0710097     4.80   0.000      .201998     .480351
//     1.debates |   .0275588    .089414     0.31   0.758    -.1476894     .202807
//  1.activities |   .0052233   .0730596     0.07   0.943    -.1379709    .1484175
//          1.rp |   .1146615   .1445102     0.79   0.428    -.1685734    .3978963
// ...

// %% [markdown]
// ## Q4

// %%
ologit q4 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application i.videos i.diagrams, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application 1.videos 1.diagrams)

ologit q4 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application)
// Out:
// Ordered logistic regression                     Number of obs     =      3,712
//                                                 LR chi2(9)        =     167.08
//                                                 Prob > chi2       =     0.0000
// Log likelihood = -5103.4984                     Pseudo R2         =     0.0161
//
// -------------------------------------------------------------------------------
//            q4 |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// 1.assessments |   .1998657   .0620809     3.22   0.001     .0781894    .3215421
// 1.explanation |   .1925607   .0715665     2.69   0.007     .0522929    .3328286
//     1.debates |   .2513452   .0907382     2.77   0.006     .0735016    .4291888
//  1.activities |   .1119418   .0734763     1.52   0.128    -.0320691    .2559528
//          1.rp |    .366519   .1461553     2.51   0.012     .0800599    .6529781
// ...

// %% [markdown]
// ## Q5

// %%
ologit q5 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application i.videos i.diagrams, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application 1.videos 1.diagrams)

ologit q5 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application)
// Out:
// Ordered logistic regression                     Number of obs     =      3,712
//                                                 LR chi2(9)        =     380.65
//                                                 Prob > chi2       =     0.0000
// Log likelihood = -5244.9043                     Pseudo R2         =     0.0350
//
// -------------------------------------------------------------------------------
//            q5 |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// 1.assessments |   .2781352   .0619473     4.49   0.000     .1567208    .3995496
// 1.explanation |   .3922105    .071702     5.47   0.000     .2516772    .5327438
//     1.debates |   .2445177   .0912614     2.68   0.007     .0656486    .4233867
//  1.activities |   .2716087   .0738043     3.68   0.000     .1269549    .4162626
//          1.rp |   .1793284   .1493083     1.20   0.230    -.1133105    .4719673
// ...

// %% [markdown]
// ## Q6

// %%
ologit q6 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application i.videos i.diagrams, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application 1.videos 1.diagrams)

ologit q6 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application)
// Out:
// Ordered logistic regression                     Number of obs     =      3,712
//                                                 LR chi2(9)        =     475.97
//                                                 Prob > chi2       =     0.0000
// Log likelihood = -5112.2844                     Pseudo R2         =     0.0445
//
// -------------------------------------------------------------------------------
//            q6 |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// 1.assessments |     .20795   .0618205     3.36   0.001     .0867839     .329116
// 1.explanation |   .6385228   .0715522     8.92   0.000     .4982831    .7787625
//     1.debates |   .3055513   .0901854     3.39   0.001      .128791    .4823115
//  1.activities |   .2157509   .0735448     2.93   0.003     .0716056    .3598961
//          1.rp |     .27323   .1458716     1.87   0.061    -.0126731     .559133
// ...

// %% [markdown]
// ## Q7

// %%
ologit q7 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application i.videos i.diagrams, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application 1.videos 1.diagrams)

ologit q7 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application)
// Out:
// Ordered logistic regression                     Number of obs     =      3,712
//                                                 LR chi2(9)        =      26.35
//                                                 Prob > chi2       =     0.0018
// Log likelihood = -5387.2796                     Pseudo R2         =     0.0024
//
// -------------------------------------------------------------------------------
//            q7 |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// 1.assessments |  -.1478995   .0618806    -2.39   0.017    -.2691834   -.0266157
// 1.explanation |  -.0496134    .070837    -0.70   0.484    -.1884514    .0892246
//     1.debates |   .0710612   .0897145     0.79   0.428     -.104776    .2468983
//  1.activities |  -.0459407   .0729914    -0.63   0.529    -.1890012    .0971197
//          1.rp |  -.3292826   .1414022    -2.33   0.020    -.6064258   -.0521394
// ...

// %%
ologit q7 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application i.videos i.diagrams, nolog
// Out:
// Ordered logistic regression                     Number of obs     =      3,712
//                                                 LR chi2(9)        =      26.35
//                                                 Prob > chi2       =     0.0018
// Log likelihood = -5387.2796                     Pseudo R2         =     0.0024
//
// -------------------------------------------------------------------------------
//            q7 |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// 1.assessments |  -.1478995   .0618806    -2.39   0.017    -.2691834   -.0266157
// 1.explanation |  -.0496134    .070837    -0.70   0.484    -.1884514    .0892246
//     1.debates |   .0710612   .0897145     0.79   0.428     -.104776    .2468983
//  1.activities |  -.0459407   .0729914    -0.63   0.529    -.1890012    .0971197
//          1.rp |  -.3292826   .1414022    -2.33   0.020    -.6064258   -.0521394
// ...

// %% [markdown]
// ## Q8

// %%
ologit q8 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application i.videos i.diagrams, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application 1.videos 1.diagrams)

ologit q8 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application)
// Out:
// Ordered logistic regression                     Number of obs     =      3,712
//                                                 LR chi2(9)        =     302.37
//                                                 Prob > chi2       =     0.0000
// Log likelihood = -5302.1624                     Pseudo R2         =     0.0277
//
// -------------------------------------------------------------------------------
//            q8 |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// 1.assessments |   .1435635   .0616487     2.33   0.020     .0227343    .2643927
// 1.explanation |   .7369232    .071443    10.31   0.000     .5968975     .876949
//     1.debates |   .2938215   .0890438     3.30   0.001     .1192988    .4683441
//  1.activities |   .1384259   .0729955     1.90   0.058    -.0046425    .2814944
//          1.rp |   .1293187   .1391471     0.93   0.353    -.1434047    .4020421
// ...

// %% [markdown]
// ## Q9

// %%
ologit q9 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application i.videos i.diagrams, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application 1.videos 1.diagrams)

ologit q9 i.assessments i.explanation i.debates i.activities i.rp i.qna i.application, nolog
estat ic
margins, dydx(1.assessments 1.explanation 1.debates 1.activities 1.rp 1.qna 1.application)
// Out:
// Ordered logistic regression                     Number of obs     =      3,712
//                                                 LR chi2(9)        =     252.37
//                                                 Prob > chi2       =     0.0000
// Log likelihood = -5558.7942                     Pseudo R2         =     0.0222
//
// -------------------------------------------------------------------------------
//            q9 |      Coef.   Std. Err.      z    P>|z|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// 1.assessments |   .1955732   .0613849     3.19   0.001     .0752611    .3158853
// 1.explanation |   .6869627   .0710054     9.67   0.000     .5477947    .8261306
//     1.debates |   .1226824    .088101     1.39   0.164    -.0499923    .2953571
//  1.activities |   -.125019   .0724598    -1.73   0.084    -.2670377    .0169996
//          1.rp |  -.1434362   .1399284    -1.03   0.305    -.4176908    .1308184
// ...
